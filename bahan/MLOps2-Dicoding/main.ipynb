# %% [markdown]
# **Set Up Pipeline TFX untuk Prediksi Penyakit Jantung**
#
# Kode ini mengimpor library, mengatur path input dan output, serta menyiapkan parameter yang diperlukan untuk menjalankan pipeline TFX menggunakan Apache Beam. Pipeline ini dirancang untuk melakukan transformasi data, tuning, pelatihan, dan evaluasi model prediksi penyakit jantung.

# %%
# Cell 1: Import library dan set up path
import os
from modules import components, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

PIPELINE_NAME = "anangrdwnsyh-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/heart_disease_transform.py"
TUNER_MODULE_FILE = "modules/heart_disease_tuner.py"
TRAINER_MODULE_FILE = "modules/heart_disease_trainer.py"

# Pipeline outputs
OUTPUT_BASE = "output"

serving_model_dir = os.path.join(OUTPUT_BASE, "serving_model")
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# Parameter untuk komponen
components_args = {
    "data_dir": DATA_ROOT,
    "transform_module": TRANSFORM_MODULE_FILE,
    "training_module": TRAINER_MODULE_FILE,
    "tuner_module": TUNER_MODULE_FILE,
    "training_steps": 1000,
    "eval_steps": 800,
    "serving_model_dir": serving_model_dir,
}

# %% [markdown]
# **Inisialisasi Komponen Pipeline TFX**
#
# Kode ini memanggil fungsi `init_components` dari modul `components` dengan parameter yang telah ditentukan dalam `components_args`. Fungsi ini menginisialisasi dan mengembalikan semua komponen yang diperlukan untuk menjalankan pipeline TFX.

# %%
# Cell 2: Inisialisasi komponen
komponen = components.init_components(**components_args)

# %% [markdown]
# **Inisialisasi dan Jalankan Pipeline TFX**
#
# Kode ini memanggil fungsi `init_pipeline` dari modul `pipeline` dengan parameter seperti `pipeline_root`, `pipeline_name`, `metadata_path`, dan `komponen` yang telah diinisialisasi. Fungsi ini mengembalikan objek pipeline yang diatur berdasarkan parameter tersebut. Selanjutnya, `BeamDagRunner()` digunakan untuk menjalankan pipeline TFX ini dengan metode `run`, yang mengatur dan mengeksekusi seluruh proses pipeline menggunakan Apache Beam.

# %%
# Cell 3: Inisialisasi dan jalankan pipeline
pipeline_obj = pipeline.init_pipeline(
    pipeline_root=pipeline_root,
    pipeline_name=PIPELINE_NAME,
    metadata_path=metadata_path,
    components=komponen
)

BeamDagRunner().run(pipeline=pipeline_obj)
# Out:
# Trial 10 Complete [00h 00m 26s]
# binary_accuracy: 0.9785000085830688
#
# Best binary_accuracy So Far: 0.9893593788146973
# Total elapsed time: 00h 02m 35s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Int', 'config': {'name': 'n_layers', 'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': None}}, {'class_name': 'Int', 'config': {'name': 'dense_units', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 32, 'sampling': None}}, {'class_name': 'Choice', 'config': {'name': 'lr', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'n_layers': 3, 'dense_units': 112, 'lr': 0.001, 'tuner/epochs': 5, 'tuner/initial_epoch': 2, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0000'}}
# INFO:absl:Best Hyperparameters are written to output\anangrdwnsyh-pipeline\Tuner\best_hyperparameters\17\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\anangrdwnsyh-pipeline\Tuner\tuner_results\17\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 17 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'best_hyperparameters': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Tuner\\best_hyperparameters\\17"
# , artifact_type: name: "HyperParameters"
# )], 'tuner_results': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Tuner\\tuner_results\\17"
# , artifact_type: name: "TunerResults"
# )]}) for execution 17
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 800,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "heart_disease_trainer@output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# Results summary
# Results in output\anangrdwnsyh-pipeline\Tuner\.system\executor_execution\17\.temp\17\kt_hyperband
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002707A0FC430>
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 112
# lr: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0000
# Score: 0.9893593788146973
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 80
# lr: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0003
# Score: 0.9821562767028809
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 112
# lr: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9808906316757202
# Trial summary
# Hyperparameters:
# n_layers: 4
# dense_units: 80
# lr: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9785000085830688
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 80
# lr: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9616249799728394
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 112
# lr: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9572031497955322
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9545781016349792
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 80
# lr: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9520312547683716
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 48
# lr: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9494843482971191
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9306718707084656
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'examples': [Artifact(artifact: id: 26
# type_id: 15
# uri: "output\\anangrdwnsyh-pipeline\\Transform\\transformed_examples\\15"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973448936
# last_update_time_since_epoch: 1720973448936
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 27
# type_id: 24
# uri: "output\\anangrdwnsyh-pipeline\\Transform\\transform_graph\\15"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973448936
# last_update_time_since_epoch: 1720973448936
# , artifact_type: id: 24
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\anangrdwnsyh-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720959538302
# last_update_time_since_epoch: 1720959538302
# , artifact_type: id: 20
# name: "Schema"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 18
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=18, input_dict={'examples': [Artifact(artifact: id: 26
# type_id: 15
# uri: "output\\anangrdwnsyh-pipeline\\Transform\\transformed_examples\\15"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973448936
# last_update_time_since_epoch: 1720973448936
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 27
# type_id: 24
# uri: "output\\anangrdwnsyh-pipeline\\Transform\\transform_graph\\15"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973448936
# last_update_time_since_epoch: 1720973448936
# , artifact_type: id: 24
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\anangrdwnsyh-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720959538302
# last_update_time_since_epoch: 1720959538302
# , artifact_type: id: 20
# name: "Schema"
# )]}, output_dict=defaultdict(<class 'list'>, {'model_run': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model_run\\18"
# , artifact_type: name: "ModelRun"
# )], 'model': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# , artifact_type: name: "Model"
# base_type: MODEL
# )]}), exec_properties={'custom_config': 'null', 'train_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'heart_disease_trainer@output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 800,\n  "splits": [\n    "eval"\n  ]\n}'}, execution_output_uri='output\\anangrdwnsyh-pipeline\\Trainer\\.system\\executor_execution\\18\\executor_output.pb', stateful_working_dir='output\\anangrdwnsyh-pipeline\\Trainer\\.system\\stateful_working_dir\\20240714-230955.189634', tmp_dir='output\\anangrdwnsyh-pipeline\\Trainer\\.system\\executor_execution\\18\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 800,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "heart_disease_trainer@output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "anangrdwnsyh-pipeline"
# , pipeline_run_id='20240714-230955.189634')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'custom_config': 'null', 'train_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'heart_disease_trainer@output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 800,\n  "splits": [\n    "eval"\n  ]\n}'} 'run_fn'
# INFO:absl:Installing 'output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\ANANG\\MLOps2\\myenv\\Scripts\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\ANANG\\AppData\\Local\\Temp\\tmp8o3nmz09', 'output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl']
# INFO:absl:Successfully installed 'output\\anangrdwnsyh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0ba17832d7f0aa3ac6ce5c27a335b74b0e5de41fc5bc675de48876c0c6514cfa-py3-none-any.whl'.
# INFO:absl:Training model.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Sex_xf (InputLayer)            [(None, 3)]          0           []
#
#  ChestPainType_xf (InputLayer)  [(None, 4)]          0           []
#
#  RestingECG_xf (InputLayer)     [(None, 4)]          0           []
#
#  ExerciseAngina_xf (InputLayer)  [(None, 3)]         0           []
#
#  FastingBS_xf (InputLayer)      [(None, 3)]          0           []
#
#  ST_Slope_xf (InputLayer)       [(None, 4)]          0           []
#
#  Age_xf (InputLayer)            [(None, 1)]          0           []
#
#  RestingBP_xf (InputLayer)      [(None, 1)]          0           []
#
#  Cholesterol_xf (InputLayer)    [(None, 1)]          0           []
#
#  MaxHR_xf (InputLayer)          [(None, 1)]          0           []
#
#  Oldpeak_xf (InputLayer)        [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 26)           0           ['Sex_xf[0][0]',
#                                                                   'ChestPainType_xf[0][0]',
#                                                                   'RestingECG_xf[0][0]',
#                                                                   'ExerciseAngina_xf[0][0]',
#                                                                   'FastingBS_xf[0][0]',
#                                                                   'ST_Slope_xf[0][0]',
#                                                                   'Age_xf[0][0]',
#                                                                   'RestingBP_xf[0][0]',
#                                                                   'Cholesterol_xf[0][0]',
#                                                                   'MaxHR_xf[0][0]',
#                                                                   'Oldpeak_xf[0][0]']
#
#  dense_6 (Dense)                (None, 256)          6912        ['concatenate_1[0][0]']
#
#  dense_7 (Dense)                (None, 64)           16448       ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 16)           1040        ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 1)            17          ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 24,417
# Trainable params: 24,417
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.2119 - binary_accuracy: 0.9163 - val_loss: 0.7149 - val_binary_accuracy: 0.8143
# Epoch 2/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0806 - binary_accuracy: 0.9693 - val_loss: 1.2078 - val_binary_accuracy: 0.8381
# Epoch 3/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0395 - binary_accuracy: 0.9858 - val_loss: 1.6547 - val_binary_accuracy: 0.8095
# Epoch 4/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0293 - binary_accuracy: 0.9895 - val_loss: 1.8146 - val_binary_accuracy: 0.8190
# Epoch 5/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0204 - binary_accuracy: 0.9926 - val_loss: 2.1296 - val_binary_accuracy: 0.8143
# Epoch 6/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0165 - binary_accuracy: 0.9945 - val_loss: 2.1875 - val_binary_accuracy: 0.8095
# Epoch 7/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0138 - binary_accuracy: 0.9955 - val_loss: 2.1903 - val_binary_accuracy: 0.8144
# Epoch 8/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0132 - binary_accuracy: 0.9960 - val_loss: 2.1256 - val_binary_accuracy: 0.8381
# Epoch 9/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0045 - binary_accuracy: 0.9988 - val_loss: 2.7384 - val_binary_accuracy: 0.8238
# Epoch 10/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0132 - binary_accuracy: 0.9959 - val_loss: 2.6708 - val_binary_accuracy: 0.8286
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: output\anangrdwnsyh-pipeline\Trainer\model\18\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\anangrdwnsyh-pipeline\Trainer\model\18\Format-Serving\assets
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# INFO:absl:Training complete. Model written to output\anangrdwnsyh-pipeline\Trainer\model\18\Format-Serving. ModelRun written to output\anangrdwnsyh-pipeline\Trainer\model_run\18
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 18 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model_run': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model_run\\18"
# , artifact_type: name: "ModelRun"
# )], 'model': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# , artifact_type: name: "Model"
# base_type: MODEL
# )]}) for execution 18
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"HeartDisease\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"ChestPainType\",\n        \"Sex\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\anangrdwnsyh-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:35921,xor_checksum:1720944034,sum_checksum:1720944034"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720959532733
# last_update_time_since_epoch: 1720959532733
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'baseline_model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720960159946
# last_update_time_since_epoch: 1720960159946
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'model': [Artifact(artifact: id: 31
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973664793
# last_update_time_since_epoch: 1720973664793
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 19
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=19, input_dict={'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\anangrdwnsyh-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:35921,xor_checksum:1720944034,sum_checksum:1720944034"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720959532733
# last_update_time_since_epoch: 1720959532733
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'baseline_model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720960159946
# last_update_time_since_epoch: 1720960159946
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'model': [Artifact(artifact: id: 31
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973664793
# last_update_time_since_epoch: 1720973664793
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )]}, output_dict=defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}), exec_properties={'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "HeartDisease"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "ChestPainType",\n        "Sex"\n      ]\n    }\n  ]\n}'}, execution_output_uri='output\\anangrdwnsyh-pipeline\\Evaluator\\.system\\executor_execution\\19\\executor_output.pb', stateful_working_dir='output\\anangrdwnsyh-pipeline\\Evaluator\\.system\\stateful_working_dir\\20240714-230955.189634', tmp_dir='output\\anangrdwnsyh-pipeline\\Evaluator\\.system\\executor_execution\\19\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"HeartDisease\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"ChestPainType\",\n        \"Sex\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "anangrdwnsyh-pipeline"
# , pipeline_run_id='20240714-230955.189634')
# INFO:absl:udf_utils.get_fn {'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "HeartDisease"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "ChestPainType",\n        "Sex"\n      ]\n    }\n  ]\n}'} 'custom_eval_shared_model'
# INFO:absl:Adding default baseline ModelSpec based on the candidate ModelSpec provided. The candidate model will be called "candidate" and the baseline will be called "baseline": updated_config=
# model_specs {
#   name: "candidate"
#   label_key: "HeartDisease"
# }
# model_specs {
#   name: "baseline"
#   label_key: "HeartDisease"
#   is_baseline: true
# }
# slicing_specs {
# }
# slicing_specs {
#   feature_keys: "ChestPainType"
#   feature_keys: "Sex"
# }
# metrics_specs {
#   metrics {
#     class_name: "AUC"
#   }
#   metrics {
#     class_name: "Precision"
#   }
#   metrics {
#     class_name: "Recall"
#   }
#   metrics {
#     class_name: "ExampleCount"
#   }
#   metrics {
#     class_name: "BinaryAccuracy"
#     threshold {
#       value_threshold {
#         lower_bound {
#           value: 0.5
#         }
#       }
#       change_threshold {
#         absolute {
#           value: 0.0001
#         }
#         direction: HIGHER_IS_BETTER
#       }
#     }
#   }
# }
#
# INFO:absl:Using output\anangrdwnsyh-pipeline\Trainer\model\18\Format-Serving as candidate model.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000270004C2DC0> and <keras.engine.input_layer.InputLayer object at 0x0000027079E86AC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000270004C2DC0> and <keras.engine.input_layer.InputLayer object at 0x0000027079E86AC0>).
# INFO:absl:Using output\anangrdwnsyh-pipeline\Trainer\model\8\Format-Serving as baseline model.
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027022732820> and <keras.engine.input_layer.InputLayer object at 0x000002702125CDC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027022732820> and <keras.engine.input_layer.InputLayer object at 0x000002702125CDC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027024BBFC40> and <keras.engine.input_layer.InputLayer object at 0x00000270227257C0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027024BBFC40> and <keras.engine.input_layer.InputLayer object at 0x00000270227257C0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002702700C970> and <keras.engine.input_layer.InputLayer object at 0x0000027024BB7640>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002702700C970> and <keras.engine.input_layer.InputLayer object at 0x0000027024BB7640>).
# c:\Users\ANANG\MLOps2\myenv\lib\site-packages\tensorflow_model_analysis\metrics\confusion_matrix_metrics.py:521: RuntimeWarning: invalid value encountered in true_divide
#   recall = tp / (tp + fn)
# INFO:absl:Evaluation complete. Results written to output\anangrdwnsyh-pipeline\Evaluator\evaluation\19.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From c:\Users\ANANG\MLOps2\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From c:\Users\ANANG\MLOps2\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result False written to output\anangrdwnsyh-pipeline\Evaluator\blessing\19.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 19 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}) for execution 19
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model_blessing': [Artifact(artifact: id: 33
# type_id: 34
# uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 16
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 31
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973692288
# last_update_time_since_epoch: 1720973692288
# , artifact_type: id: 34
# name: "ModelBlessing"
# )], 'model': [Artifact(artifact: id: 31
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973664793
# last_update_time_since_epoch: 1720973664793
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 20
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=20, input_dict={'model_blessing': [Artifact(artifact: id: 33
# type_id: 34
# uri: "output\\anangrdwnsyh-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 16
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 31
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973692288
# last_update_time_since_epoch: 1720973692288
# , artifact_type: id: 34
# name: "ModelBlessing"
# )], 'model': [Artifact(artifact: id: 31
# type_id: 31
# uri: "output\\anangrdwnsyh-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1720973664793
# last_update_time_since_epoch: 1720973664793
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'push_destination': '{\n  "filesystem": {\n    "base_directory": "output\\\\serving_model"\n  }\n}', 'custom_config': 'null'}, execution_output_uri='output\\anangrdwnsyh-pipeline\\Pusher\\.system\\executor_execution\\20\\executor_output.pb', stateful_working_dir='output\\anangrdwnsyh-pipeline\\Pusher\\.system\\stateful_working_dir\\20240714-230955.189634', tmp_dir='output\\anangrdwnsyh-pipeline\\Pusher\\.system\\executor_execution\\20\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240714-230955.189634"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "anangrdwnsyh-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240714-230955.189634"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "anangrdwnsyh-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "anangrdwnsyh-pipeline"
# , pipeline_run_id='20240714-230955.189634')
# INFO:absl:Model on output\anangrdwnsyh-pipeline\Evaluator\blessing\19 was not blessed by model validation
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 20 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\anangrdwnsyh-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 20
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
